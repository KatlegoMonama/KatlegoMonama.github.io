# %% [markdown]
# # 01_EDA - Exploratory Data Analysis
#
# This notebook contains initial data loading, summary statistics, and key visualizations. Replace placeholder cells with your dataset-specific code.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)
